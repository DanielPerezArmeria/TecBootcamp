# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# %%
facilities = pd.read_csv("Resources/health-facilities-gh.csv")
tiers = pd.read_csv("Resources/health-facility-tiers.csv")

print(facilities.head())
print()
print("---------------------------------------------------------------------")
print()
print(tiers.head())
# Out:
#     Region          District             FacilityName           Type  \
# 0  Ashanti     Offinso North        A.M.E Zion Clinic         Clinic
# 1  Ashanti  Bekwai Municipal        Abenkyiman Clinic         Clinic
# 2  Ashanti      Adansi North     Aboabo Health Centre  Health Centre
# 3  Ashanti     Afigya-Kwabre  Aboabogya Health Centre  Health Centre
# 4  Ashanti            Kwabre     Aboaso Health Centre  Health Centre
#
#            Town   Ownership  Latitude  Longitude
# 0      Afrancho        CHAG   7.40801   -1.96317
# 1  Anwiankwanta     Private   6.46312   -1.58592
# 2   Aboabo No 2  Government   6.22393   -1.34982
# 3     Aboabogya  Government   6.84177   -1.61098
# 4        Aboaso  Government   6.84177   -1.61098
#
# ---------------------------------------------------------------------
#
#     Region                   Facility  Tier
# 0  Ashanti    PEACE AND LOVE HOSPITAL     2
# 1  Ashanti             TODAH HOSPITAL     2
# 2  Ashanti  ASOKWA CHILREN'S HOSPITAL     2
# 3  Ashanti       FANKYEBEBRA HOSPITAL     2
# 4  Ashanti           MICHMIT HOSPITAL     2

# %%
# Data clean. Create 3 base tables: "Regions", "Districts", "Facilities"
# There are failities that are not classified in tiers.

# Standarize column names
tiers.columns = ["Region", "FacilityName", "Tier"]

# Facility name to uppercase in the Facilities table, to match the format in the Tiers dataframe
facilities.FacilityName = facilities.FacilityName.str.upper()

# %%
# Find out how many facilities in Ghana are not categorized by tiers

f = pd.merge(facilities, tiers, on="FacilityName", how="left")
f.count()
# Out:
# Region_x        3768
# District        3768
# FacilityName    3768
# Type            3768
# Town            3615
# Ownership       3768
# Latitude        3744
# Longitude       3744
# Region_y         229
# Tier             229
# dtype: int64

# %%
# First conclusion: Most healthcare facilities in Ghana are not categorized by tiers, therefore, it is difficult
# to determin the healthcare capacity of a district

# Second: There are facilities mentioned in the Tier table, but do not exist in the Facilities table.

# %%
# Get the Region table
regions = pd.DataFrame( facilities["Region"].unique() )
regions = regions.reset_index()
regions.columns = ["id", "region"]
regions
# Out:
#    id         region
# 0   0        Ashanti
# 1   1    Brong Ahafo
# 2   2        Central
# 3   3        Eastern
# 4   4  Greater Accra
# 5   5       Northern
# 6   6     Upper East
# 7   7     Upper West
# 8   8          Volta
# 9   9        Western

# %%
# Store it in Postgress
rds_connection_string = "postgres:Talegazo0931@localhost:5432/GhanaHealthcare"
engine = create_engine(f'postgresql://{rds_connection_string}')
engine.table_names()
# Out:
# ['regions', 'districts']

# %%
regions.to_sql(name='regions', con=engine, if_exists='append', index=False)
regionsId = pd.read_sql_query('select * from regions', con=engine)
regionsId.head()
# Out:
#    id         region
# 0   0        Ashanti
# 1   1    Brong Ahafo
# 2   2        Central
# 3   3        Eastern
# 4   4  Greater Accra

# %%
facilitiesId = pd.merge(facilities, regionsId, left_on="Region", right_on="region", how="inner")
facilitiesId.head(6)
# Out:
#     Region          District             FacilityName           Type  \
# 0  Ashanti     Offinso North        A.M.E ZION CLINIC         Clinic
# 1  Ashanti  Bekwai Municipal        ABENKYIMAN CLINIC         Clinic
# 2  Ashanti      Adansi North     ABOABO HEALTH CENTRE  Health Centre
# 3  Ashanti     Afigya-Kwabre  ABOABOGYA HEALTH CENTRE  Health Centre
# 4  Ashanti            Kwabre     ABOASO HEALTH CENTRE  Health Centre
# 5  Ashanti     Offinso North   ABOFFOUR HEALTH CENTRE  Health Centre
#
#            Town   Ownership  Latitude  Longitude  id   region
# 0      Afrancho        CHAG   7.40801   -1.96317   0  Ashanti
# 1  Anwiankwanta     Private   6.46312   -1.58592   0  Ashanti
# 2   Aboabo No 2  Government   6.22393   -1.34982   0  Ashanti
# 3     Aboabogya  Government   6.84177   -1.61098   0  Ashanti
# 4        Aboaso  Government   6.84177   -1.61098   0  Ashanti
# 5      Aboffour  Government   7.12986   -1.73294   0  Ashanti

# %%
# Create the unique districts table and store them in the database
districts = facilitiesId[["District", "id"]]
districts = districtId.drop_duplicates()
districts = districts.reset_index()
districts.columns= ["id", "district", "region_id"]
districts
# Out:
#        id                     district  region_id
# 0       0                Offinso North          0
# 1       1             Bekwai Municipal          0
# 2       2                 Adansi North          0
# 3       3                Afigya-Kwabre          0
# 4       4                       Kwabre          0
# 5       6             Atwima-Nwabiagya          0
# 6       7              Atwima-Kwanwoma          0
# 7       8       Ejisu-Juaben Municipal          0
# 8       9            Mampong Municipal          0
# 9      10                 Amansie West          0
# 10     11  Asante-Akim North Municipal          0
# 11     12              Ahafo-Ano South          0
# 12     14                Sekyere South          0
# 13     15              Sekyere Central          0
# 14     20             Obuasi Municipal          0
# 15     23                 Sekyere East          0
# 16     26                 Adansi South          0
# 17     31              Amansie Central          0
# 18     37              Ahafo-Ano North          0
# 19     47                     Bosomtwe          0
# 20     66         Sekyere Afram Plains          0
# 21     79                 Bosome Freho          0
# 22     89          Ejura Sekyeredumasi          0
# 23     90            Asante-Akim South          0
# 24     94                Atwima-Mponua          0
# 25    109            Offinso Municipal          0
# 26    375          Kumasi Metropolitan          0
# 27    658      Asunafo North Municipal          1
# 28    671                Asunafo South          1
# 29    678                      Asutifi          1
# ..    ...                          ...        ...
# 141  2988                         Keta          8
# 142  3012                         Ketu          8
# 143  3045                       Kpando          8
# 144  3065                  Krachi East          8
# 145  3073                  Krachi West          8
# 146  3084                      Nkwanta          8
# 147  3105                  North Tongu          8
# 148  3119                   South Dayi          8
# 149  3131                  South Tongu          8
# 150  3237                       Akatsi          8
# 151  3260                  Ahanta West          9
# 152  3281                 Aowin Suaman          9
# 153  3296                          Bia          9
# 154  3331      Bibiani-Anhwiaso-Bekwai          9
# 155  3340                    Ellembele          9
# 156  3350                       Jomoro          9
# 157  3368                      Juabeso          9
# 158  3387            Mpohor-Wassa East          9
# 159  3394          Prestea-Huni Valley          9
# 160  3407                   Nzema East          9
# 161  3409         Nzema East Municipal          9
# 162  3422                 Sefwi Wiawso          9
# 163  3423             Sefwi-Akontombra          9
# 164  3439            Shama Ahanta East          9
# 165  3443                        Shama          9
# 166  3499            Wassa-Amenfi East          9
# 167  3501                   Wassa West          9
# 168  3506      Tarkwa Nsuaem Municipal          9
# 169  3545            Wassa-Amenfi West          9
# 170  3698           Pretea-Huni Valley          9
#
# [171 rows x 3 columns]

# %%
districts.to_sql(name='districts', con=engine, if_exists='replace', index=False)
districtsId = pd.read_sql_query('select * from districts', con=engine)
districtsId.head()
# Out:
#    id          district  region_id
# 0   0     Offinso North          0
# 1   1  Bekwai Municipal          0
# 2   2      Adansi North          0
# 3   3     Afigya-Kwabre          0
# 4   4            Kwabre          0

# %%
# Get the Facilities and store them in the database
namesId = pd.merge(facilitiesId, districts, left_on="District", right_on="district", how="inner")
namesId = namesId[["FacilityName", "Type", "Ownership", "Latitude", "Longitude", "id_y"]]
namesId.columns = ["facility", "type", "ownership", "latitude", "longitude", "district_id"]
namesId = namesId.reset_index()
namesId = pd.merge(namesId, tiers, left_on="facility", right_on="FacilityName", how="left")
namesId = namesId[["facility", "type", "ownership", "latitude", "longitude", "district_id", "Tier"]]
namesId = namesId.rename(columns={"Tier":"tier"})
namesId = namesId.fillna(0)
namesId = namesId.reset_index()
namesId = namesId.rename(columns={"index":"id"})
namesId
# Out:
#         id                                    facility                  type  \
# 0        0                           A.M.E ZION CLINIC                Clinic
# 1        1                      ABOFFOUR HEALTH CENTRE         Health Centre
# 2        2                      AKOMADAN HEALTH CENTRE         Health Centre
# 3        3                       ANYINASUSU SDA CENTRE                Clinic
# 4        4                      DORCAS MEMORIAL CLINIC                Clinic
# 5        5                  NKENKASU DISTRICT HOSPITAL     District Hospital
# 6        6                        NYAMEBEKYERE CLIINIC                Clinic
# 7        7                           ABENKYIMAN CLINIC                Clinic
# 8        8                  AHMADIYAA MISSION HOSPITAL              Hospital
# 9        9                    AHWENE MEMORIAL HOSPITAL              Hospital
# 10      10                    AKOMAA MEMORIAL HOSPITAL              Hospital
# 11      11                  BEKWAI GOVERNMENT HOSPITAL     District Hospital
# 12      12                     KOKOFU GENERAL HOSPITAL              Hospital
# 13      13                        NANCY POWEL'S CLINIC                Clinic
# 14      14                             NEW LIFE CLINIC                Clinic
# 15      15                                SDA HOSPITAL              Hospital
# 16      16                     SHALOM METHODIST CLINIC                Clinic
# 17      17                           ST. MARY'S CLINIC                Clinic
# 18      18                        ST. STEPHEN'S CLINIC                Clinic
# 19      19                    TINKWAMAH MATERNITY HOME        Maternity Home
# 20      20    KOKOFU HEALTH ASSISTANTS TRAINING SCHOOL  Training Institution
# 21      21                                 BONI CLINIC                Clinic
# 22      22                        ABOABO HEALTH CENTRE         Health Centre
# 23      23                             AKROFROM CLINIC                Clinic
# 24      24                     AKROKERRI HEALTH CENTRE         Health Centre
# 25      25                        ASOKWA HEALTH CENTRE         Health Centre
# 26      26           BODWESANGO ST LOUIS HEALTH CENTRE         Health Centre
# 27      27         DOMPOASE BENITO MENNI HEALTH CENTRE         Health Centre
# 28      28                        FOMENA HEALTH CENTRE         Health Centre
# 29      29                         FUMSO HEALTH CENTRE         Health Centre
# ...    ...                                         ...                   ...
# 3738  3738                             NKWANTANUM CHPS                  CHPS
# 3739  3739                                MOSEASO CHPS                  CHPS
# 3740  3740                              BISAASO CLINIC                Clinic
# 3741  3741                           AGONA CAMP CLINIC                Clinic
# 3742  3742                              KWABENG CLINIC                Clinic
# 3743  3743                              SOMPREY CLINIC                Clinic
# 3744  3744                               BOKAKORE CHPS                  CHPS
# 3745  3745                            ATTOBRAKROM CHPS                  CHPS
# 3746  3746                                 DUNKWA CHPS                  CHPS
# 3747  3747                          ASANCO SHS SICKBAY                Clinic
# 3748  3748                                 ANAKUM CHPS                  CHPS
# 3749  3749                              AKYEKYERE CHPS                  CHPS
# 3750  3750                                 KWAMAN CHPS                  CHPS
# 3751  3751                                SAMREBOI RCH                   RCH
# 3752  3752  GOLDEN STAR BOGOOSO PRESTEA LIMITED CLINIC                Clinic
# 3753  3753                              NSUSUADEN CHPS                  CHPS
# 3754  3754                                 HUNISO CHPS                  CHPS
# 3755  3755                         HIMAN HEALTH CENTRE         Health Centre
# 3756  3756                 PRESTEA GOVERNMENT HOSPITAL              Hospital
# 3757  3757                                ASOAMPA CHPS                  CHPS
# 3758  3758                                 PRESTEA RCH                Clinic
# 3759  3759                 ODOYE FIRST AID POST CLINIC                Clinic
# 3760  3760                   HUNI VALLEY HEALTH CENTRE         Health Centre
# 3761  3761                                 DAMANG CHPS                  CHPS
# 3762  3762       GOLDFIEDS GHANA LIMITED DAMANG CLINIC                Clinic
# 3763  3763                               BOMPIESO CHPS                  CHPS
# 3764  3764                         ABOSO HEALTH CENTRE         Health Centre
# 3765  3765            SDA WASSA NKRAN COMMUNITY CLINIC                Clinic
# 3766  3766                         ADOM MATERNITY HOME        Maternity Home
# 3767  3767                                ASIKUMA CHPS                  CHPS
#
#        ownership  latitude  longitude  district_id  tier
# 0           CHAG  7.408010  -1.963170            0   0.0
# 1     Government  7.129860  -1.732940            0   0.0
# 2     Government  7.405810  -1.960720            0   0.0
# 3           CHAG  7.014840  -1.708740            0   0.0
# 4           CHAG  7.396940  -1.952970            0   0.0
# 5     Government  7.319570  -1.902890            0   0.0
# 6        Private  6.597212  -1.578999            0   0.0
# 7        Private  6.463120  -1.585920            1   3.0
# 8        Private  6.509860  -1.536490            1   0.0
# 9        Private  6.454910  -1.570710            1   0.0
# 10          CHAG  6.439660  -1.538370            1   0.0
# 11    Government  6.456050  -1.578570            1   0.0
# 12    Government  6.499030  -1.522540            1   0.0
# 13          CHAG  6.317880  -1.308040            1   0.0
# 14          CHAG  6.472840  -1.436770            1   0.0
# 15          CHAG  6.310400  -1.391100            1   0.0
# 16          CHAG  6.364940  -1.366450            1   0.0
# 17          CHAG  6.451210  -1.368360            1   0.0
# 18       Private  6.480400  -1.495100            1   0.0
# 19       Private  6.451390  -1.565370            1   0.0
# 20    Government  6.450000  -1.583333            1   0.0
# 21    Government  6.450000  -1.583333            1   0.0
# 22    Government  6.223930  -1.349820            2   0.0
# 23       Private  6.153480  -1.476210            2   0.0
# 24    Government  6.295130  -1.632240            2   0.0
# 25    Government  6.280680  -1.507860            2   0.0
# 26          CHAG  6.222490  -1.310310            2   0.0
# 27          CHAG  6.322820  -1.544680            2   0.0
# 28    Government  6.280220  -1.510020            2   0.0
# 29    Government  6.110480  -1.448540            2   0.0
# ...          ...       ...        ...          ...   ...
# 3738  Government  5.653611  -2.165901         3545   0.0
# 3739  Government  5.653611  -2.165901         3545   0.0
# 3740  Government  5.653611  -2.165901         3545   0.0
# 3741  Government  5.653611  -2.165901         3545   0.0
# 3742     Private  5.653611  -2.165901         3545   0.0
# 3743  Government  5.653611  -2.165901         3545   0.0
# 3744  Government  5.653611  -2.165901         3545   0.0
# 3745  Government  5.653611  -2.165901         3545   0.0
# 3746  Government  5.653611  -2.165901         3545   0.0
# 3747     Private  5.653611  -2.165901         3545   0.0
# 3748  Government  5.653611  -2.165901         3545   0.0
# 3749  Government  5.653611  -2.165901         3545   0.0
# 3750  Government  5.653611  -2.165901         3545   0.0
# 3751  Government  5.653611  -2.165901         3545   0.0
# 3752  Government  5.434363  -2.143448         3698   0.0
# 3753  Government  5.434363  -2.143448         3698   0.0
# 3754  Government  5.434363  -2.143448         3698   0.0
# 3755  Government  5.434363  -2.143448         3698   0.0
# 3756  Government  5.434363  -2.143448         3698   0.0
# 3757  Government  5.434363  -2.143448         3698   0.0
# 3758  Government  5.434363  -2.143448         3698   0.0
# 3759     Private  5.434363  -2.143448         3698   0.0
# 3760  Government  5.434363  -2.143448         3698   0.0
# 3761  Government  5.434363  -2.143448         3698   0.0
# 3762     Private  5.434363  -2.143448         3698   0.0
# 3763  Government  5.434363  -2.143448         3698   0.0
# 3764  Government  5.434363  -2.143448         3698   0.0
# 3765     Private  5.434363  -2.143448         3698   0.0
# 3766     Private  5.434363  -2.143448         3698   0.0
# 3767  Government  5.434363  -2.143448         3698   0.0
#
# [3768 rows x 8 columns]

# %%
namesId.to_sql(name='facilities', con=engine, if_exists='replace', index=False)
names = pd.read_sql_query('select * from facilities', con=engine)
names.head()
# Out:
#    id                facility           type   ownership  latitude  longitude  \
# 0   0       A.M.E ZION CLINIC         Clinic        CHAG   7.40801   -1.96317
# 1   1  ABOFFOUR HEALTH CENTRE  Health Centre  Government   7.12986   -1.73294
# 2   2  AKOMADAN HEALTH CENTRE  Health Centre  Government   7.40581   -1.96072
# 3   3   ANYINASUSU SDA CENTRE         Clinic        CHAG   7.01484   -1.70874
# 4   4  DORCAS MEMORIAL CLINIC         Clinic        CHAG   7.39694   -1.95297
#
#    district_id  tier
# 0            0   0.0
# 1            0   0.0
# 2            0   0.0
# 3            0   0.0
# 4            0   0.0
